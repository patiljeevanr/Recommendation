# %%
# %matplotlib inline

import pandas
from sklearn.cross_validation import train_test_split
import numpy as np
import time
from sklearn.externals import joblib
import Recommenders as Recommenders
import Evaluation as Evaluation
# Out:
# /home/mauli/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
#Read userid-songid-listen_count triplets
#This step might take time to download data from external sources
triplets_file = '10000.txt'
songs_metadata_file = 'song_data.csv'

song_df_1 = pandas.read_table(triplets_file,header=None)
song_df_1.columns = ['user_id', 'song_id', 'listen_count']

#Read song  metadata
song_df_2 =  pandas.read_csv(songs_metadata_file)

#Merge the two dataframes above to create input dataframe for recommender systems
song_df = pandas.merge(song_df_1, song_df_2.drop_duplicates(['song_id']), on="song_id", how="left")

# %%
song_df.head()
# Out:
#                                     user_id             song_id  listen_count  \
# 0  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOAKIMP12A8C130995             1
# 1  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBBMDR12A8C13253B             2
# 2  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBXHDL12A81C204C0             1
# 3  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBYHAJ12A6701BF1D             1
# 4  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SODACBL12A8C13C273             1
#
#              title                        release    artist_name  year
# 0         The Cove             Thicker Than Water   Jack Johnson     0
# 1  Entre Dos Aguas            Flamenco Para Niños  Paco De Lucia  1976
# 2         Stronger                     Graduation     Kanye West  2007
# 3   Constellations              In Between Dreams   Jack Johnson  2005
# 4     Learn To Fly  There Is Nothing Left To Lose   Foo Fighters  1999

# %%
len(song_df)
# Out:
# 2000000

# %%
#for small dataset
#song_df = song_df.head(10000)

#Merge song title and artist_name columns to make a merged column
song_df['song'] = song_df['title'].map(str) + " - " + song_df['artist_name']

# %%
song_grouped = song_df.groupby(['song']).agg({'listen_count': 'count'}).reset_index()
grouped_sum = song_grouped['listen_count'].sum()
song_grouped['percentage']  = song_grouped['listen_count'].div(grouped_sum)*100
song_grouped.sort_values(['listen_count', 'song'], ascending = [0,1]).head()
# Out:
#                                                    song  listen_count  \
# 7127                           Sehr kosmisch - Harmonia          8277
# 9084                                       Undo - Björk          7032
# 2068  Dog Days Are Over (Radio Edit) - Florence + Th...          6949
# 9880                     You're The One - Dwight Yoakam          6412
# 6774                            Revelry - Kings Of Leon          6145
#
#       percentage
# 7127     0.41385
# 9084     0.35160
# 2068     0.34745
# 9880     0.32060
# 6774     0.30725

# %%
users = song_df['user_id'].unique()
len(users)
# Out:
# 76353

# %%
songs = song_df['song'].unique()
len(songs)
# Out:
# 9953

# %%
train_data, test_data = train_test_split(song_df, test_size = 0.20, random_state=0)
train_data.head(5)
# Out:
#                                           user_id             song_id  \
# 608812   7b8fbe766a49e5d7618452149dfab920621fc4fb  SOJJYDE12AF729FC16
# 623729   d24956cd68ff84b6d0271286ae6866ee1c89ff77  SOPQGWI12A8C135DDB
# 583106   da7b91b6cab1ca11227ee7720c4d2e03e8c31579  SOCOIIG12A58A7D151
# 435735   5f633da6ad4845350949c3c76ce6c4ef6f167476  SOQQTBB12AB0182F1D
# 1361953  01ad0fabd01af750700a1e80bb0055abcb3edd28  SOVYNVS12AC3DF64AB
#
#          listen_count                      title  \
# 608812              1     Two Is Better Than One
# 623729              2              Royal Gregory
# 583106              1                 Mr Sandman
# 435735              2  A Days Work (feat. P.O.S)
# 1361953             2      Rockin' Rollin' Stone
#
#                               release                             artist_name  \
# 608812                     Love Drunk  Boys Like Girls featuring Taylor Swift
# 623729                             LP                               Holy Fuck
# 583106            Original Hits - 50s                          The Chordettes
# 435735               Rádio do Canibal                                  BK-One
# 1361953  100 Greatest Rockabilly Hits                              Andy Starr
#
#          year                                               song
# 608812   2009  Two Is Better Than One - Boys Like Girls featu...
# 623729   2007                          Royal Gregory - Holy Fuck
# 583106   1993                        Mr Sandman - The Chordettes
# 435735      0                 A Days Work (feat. P.O.S) - BK-One
# 1361953  2000                 Rockin' Rollin' Stone - Andy Starr

# %%
pm = Recommenders.popularity_recommender_py()
pm.create(train_data, 'user_id', 'song')
user_id = users[5]
pm.recommend(user_id)
# Out:
#                                        user_id  \
# 7127  4bd88bfb25263a75bbdd467e74018f4ae570e5df
# 9084  4bd88bfb25263a75bbdd467e74018f4ae570e5df
# 2068  4bd88bfb25263a75bbdd467e74018f4ae570e5df
# 9880  4bd88bfb25263a75bbdd467e74018f4ae570e5df
# 6774  4bd88bfb25263a75bbdd467e74018f4ae570e5df
# 7115  4bd88bfb25263a75bbdd467e74018f4ae570e5df
# 3613  4bd88bfb25263a75bbdd467e74018f4ae570e5df
# 2717  4bd88bfb25263a75bbdd467e74018f4ae570e5df
# 3485  4bd88bfb25263a75bbdd467e74018f4ae570e5df
# 8847  4bd88bfb25263a75bbdd467e74018f4ae570e5df
#
#                                                    song  score  Rank
# 7127                           Sehr kosmisch - Harmonia   6630   1.0
# 9084                                       Undo - Björk   5639   2.0
# 2068  Dog Days Are Over (Radio Edit) - Florence + Th...   5592   3.0
# 9880                     You're The One - Dwight Yoakam   5143   4.0
# 6774                            Revelry - Kings Of Leon   4938   5.0
# 7115                              Secrets - OneRepublic   4627   6.0
# 3613  Horn Concerto No. 4 in E flat K495: II. Romanc...   4368   7.0
# 2717                     Fireflies - Charttraxx Karaoke   3835   8.0
# 3485                           Hey_ Soul Sister - Train   3819   9.0
# 8847                                 Tive Sim - Cartola   3707  10.0

# %%
is_model = Recommenders.item_similarity_recommender_py()
is_model.create(train_data, 'user_id', 'song')

# %%
#Print the songs for the user in training data
user_id = users[5]
user_items = is_model.get_user_items(user_id)
#
print("------------------------------------------------------------------------------------")
print("Training data songs for the user userid: %s:" % user_id)
print("------------------------------------------------------------------------------------")

for user_item in user_items:
    print(user_item)

print("----------------------------------------------------------------------")
print("Recommendation process going on:")
print("----------------------------------------------------------------------")

#Recommend songs for the user using personalized model
is_model.recommend(user_id)
# Out:
# ------------------------------------------------------------------------------------
# Training data songs for the user userid: 4bd88bfb25263a75bbdd467e74018f4ae570e5df:
# ------------------------------------------------------------------------------------
# The Real Slim Shady - Eminem
# Forgive Me - Leona Lewis
# Say My Name - Destiny's Child
# Speechless - Lady GaGa
# Ghosts 'n' Stuff (Original Instrumental Mix) - Deadmau5
# Missing You - John Waite
# Without Me - Eminem
# Somebody To Love - Justin Bieber
# Just Lose It - Eminem
# ----------------------------------------------------------------------
# Recommendation process going on:
# ----------------------------------------------------------------------
# No. of unique songs for the user: 9
# no. of unique songs in the training set: 9953
# Non zero values in cooccurence_matrix :60670
#                                     user_id  \
# 0  4bd88bfb25263a75bbdd467e74018f4ae570e5df
# 1  4bd88bfb25263a75bbdd467e74018f4ae570e5df
# 2  4bd88bfb25263a75bbdd467e74018f4ae570e5df
# 3  4bd88bfb25263a75bbdd467e74018f4ae570e5df
# 4  4bd88bfb25263a75bbdd467e74018f4ae570e5df
# 5  4bd88bfb25263a75bbdd467e74018f4ae570e5df
# 6  4bd88bfb25263a75bbdd467e74018f4ae570e5df
# 7  4bd88bfb25263a75bbdd467e74018f4ae570e5df
# 8  4bd88bfb25263a75bbdd467e74018f4ae570e5df
# 9  4bd88bfb25263a75bbdd467e74018f4ae570e5df
#
#                                              song     score rank
# 0                            Mockingbird - Eminem  0.057775    1
# 1                             My Name Is - Eminem  0.056529    2
# 2                         U Smile - Justin Bieber  0.045514    3
# 3                 Terre Promise - O'Rosko Raricim  0.044706    4
# 4  Eenie Meenie - Sean Kingston and Justin Bieber  0.043548    5
# 5                    Superman - Eminem / Dina Rae  0.042890    6
# 6                          Hailie's Song - Eminem  0.041370    7
# 7                         Love Me - Justin Bieber  0.041012    8
# 8             Drop The World - Lil Wayne / Eminem  0.040764    9
# 9                 OMG - Usher featuring will.i.am  0.039818   10

# %%
is_model.get_similar_items(['U Smile - Justin Bieber'])
# Out:
# no. of unique songs in the training set: 9953
# Non zero values in cooccurence_matrix :7604
#   user_id                                            song     score rank
# 0                                 Love Me - Justin Bieber  0.213793    1
# 1                        Somebody To Love - Justin Bieber  0.206537    2
# 2          Eenie Meenie - Sean Kingston and Justin Bieber  0.203704    3
# 3                    One Less Lonely Girl - Justin Bieber  0.177065    4
# 4                                One Time - Justin Bieber  0.170461    5
# 5                       That Should Be Me - Justin Bieber  0.166469    6
# 6                     Stuck In The Moment - Justin Bieber  0.161861    7
# 7                           Down To Earth - Justin Bieber  0.159392    8
# 8                            Runaway Love - Justin Bieber  0.137355    9
# 9                                      Up - Justin Bieber  0.135096   10

# %%
start = time.time()

#Define what percentage of users to use for precision recall calculation
user_sample = 0.005

#Instantiate the precision_recall_calculator class
pr = Evaluation.precision_recall_calculator(test_data, train_data, pm, is_model)

#Call method to calculate precision and recall values
(pm_avg_precision_list, pm_avg_recall_list, ism_avg_precision_list, ism_avg_recall_list) = pr.calculate_measures(user_sample)

end = time.time()
print(end - start)
# Out:
# Length of user_test_and_training:68327
# Length of user sample:341
# Getting recommendations for user:884f606371c3f88b19b0bc04475290a2d9221d73
# No. of unique songs for the user: 17
# no. of unique songs in the training set: 9953
# Non zero values in cooccurence_matrix :87896
# Getting recommendations for user:64c63b761dfe4677a0349287ba49eee9046fdff4
# No. of unique songs for the user: 6
# no. of unique songs in the training set: 9953
# Non zero values in cooccurence_matrix :34372
# Getting recommendations for user:31fbcfb45d1543d5a806156698ebef71058cb0fa
# No. of unique songs for the user: 12
# no. of unique songs in the training set: 9953
# Non zero values in cooccurence_matrix :85191
# Getting recommendations for user:4a0fa91ab53d0cfde6e5da4e197bce0272e5bb87
# No. of unique songs for the user: 12
# no. of unique songs in the training set: 9953
# Non zero values in cooccurence_matrix :60624
# Getting recommendations for user:82105117087e3979c13f0ec25be3ea8656f0d8cc
# No. of unique songs for the user: 14
# no. of unique songs in the training set: 9953
# Non zero values in cooccurence_matrix :91417
# Getting recommendations for user:f32fc584b1a4856ac294d627f9e5b542ddf0accc
# No. of unique songs for the user: 21
# no. of unique songs in the training set: 9953
# Non zero values in cooccurence_matrix :86036
# Getting recommendations for user:2150e7b0670625935735a47f4af6c8f9379116c8
# No. of unique songs for the user: 20
# no. of unique songs in the training set: 9953
# Non zero values in cooccurence_matrix :94826
# Getting recommendations for user:eb20341bbefd3c1d9848aaa3334d07f8bca558e8
# No. of unique songs for the user: 14
# no. of unique songs in the training set: 9953
# Non zero values in cooccurence_matrix :81758
# Getting recommendations for user:6ac926c3d912f13df9246ee522613f513d7bee0c
# No. of unique songs for the user: 12
# no. of unique songs in the training set: 9953
# Non zero values in cooccurence_matrix :61037
# Getting recommendations for user:a6fe4285e85bc991d203b1fc796b5fad388cac7d
# No. of unique songs for the user: 11
# no. of unique songs in the training set: 9953
# Non zero values in cooccurence_matrix :68125
# Getting recommendations for user:705d7fb0aff3a415f85e34ce8ea81a0f20ec4031
# No. of unique songs for the user: 18
# no. of unique songs in the training set: 9953
# Non zero values in cooccurence_matrix :86136
# Getting recommendations for user:8cd3fae4a01df761fbacd99b1584494b84f4ec09
# No. of unique songs for the user: 7
# no. of unique songs in the training set: 9953
# Non zero values in cooccurence_matrix :51106
# Getting recommendations for user:1b40252dc7cb679d8bb2dbf36a7344251fde8625
# No. of unique songs for the user: 8
# no. of unique songs in the training set: 9953
# Non zero values in cooccurence_matrix :42550
# Getting recommendations for user:8eb255c956b79ca1b076a0defc09e9dc15eae0e5
# No. of unique songs for the user: 32
# no. of unique songs in the training set: 9953
# Non zero values in cooccurence_matrix :248035
# Getting recommendations for user:25a9451387cd1b472322464bfd734c3a856f6818
# No. of unique songs for the user: 14
# no. of unique songs in the training set: 9953
# Non zero values in cooccurence_matrix :80112
# Getting recommendations for user:a1fdacd430cdd8335ee9eca54ca7f0fe09fd44c7
# No. of unique songs for the user: 23
# no. of unique songs in the training set: 9953
# Non zero values in cooccurence_matrix :202758
# Getting recommendations for user:2b9a08420a72a88f89ab3b31bd106d06f5c5825d
# No. of unique songs for the user: 80
# no. of unique songs in the training set: 9953
# Non zero values in cooccurence_matrix :484600
# Getting recommendations for user:b01921ae241dd614e6b05018ce6b9d8c110ca9b7
# No. of unique songs for the user: 26
# no. of unique songs in the training set: 9953
# Non zero values in cooccurence_matrix :123966
# Getting recommendations for user:425d523c6105eaeb75448f0ffeb1c08a9797479f
# No. of unique songs for the user: 11
# no. of unique songs in the training set: 9953
# Non zero values in cooccurence_matrix :36206
# Getting recommendations for user:68a71f88da2a1fe145b532117b2e5bb079981de4
# No. of unique songs for the user: 20
# no. of unique songs in the training set: 9953
# Non zero values in cooccurence_matrix :85627
# Getting recommendations for user:89d27797088469a97dd78720af30e1444af5a218
# No. of unique songs for the user: 28
# no. of unique songs in the training set: 9953
# Non zero values in cooccurence_matrix :202491
# Getting recommendations for user:f7856349e8b6078d41bf14a348f76fa5cb65baa2
# No. of unique songs for the user: 14
# no. of unique songs in the training set: 9953

# %%
import pylab as pl

#Method to generate precision and recall curve
def plot_precision_recall(m1_precision_list, m1_recall_list, m1_label, m2_precision_list, m2_recall_list, m2_label):
    pl.clf()    
    pl.plot(m1_recall_list, m1_precision_list, label=m1_label)
    pl.plot(m2_recall_list, m2_precision_list, label=m2_label)
    pl.xlabel('Recall')
    pl.ylabel('Precision')
    pl.ylim([0.0, 0.20])
    pl.xlim([0.0, 0.20])
    pl.title('Precision-Recall curve')
    #pl.legend(loc="upper right")
    pl.legend(loc=9, bbox_to_anchor=(0.5, -0.2))
    pl.show()

# %%
print("Plotting precision recall curves.")

plot_precision_recall(pm_avg_precision_list, pm_avg_recall_list, "popularity_model",
                      ism_avg_precision_list, ism_avg_recall_list, "item_similarity_model")
